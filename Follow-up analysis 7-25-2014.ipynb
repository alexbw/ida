# %%
import pandas as pd
import numpy as np
from sklearn import svm, cross_validation
from sklearn import tree, preprocessing
from sklearn import decomposition as decomp
from sklearn import manifold
from sklearn import linear_model
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
np.set_printoptions(suppress=True, precision=3)
from util import *

# %% [markdown]
# ### Load the data

# %%
# Load it up
sdf = pd.load("/Users/Alex/Code/blurd/data.pandas")

data = np.array([extract_redness(i).mean(1) for i in sdf.image.values])
orig_data = data.copy()
min_length = np.min([len(d) for d in orig_data])
orig_data = np.array([d[:min_length] for d in orig_data])
plug_pos = np.array([detect_plug(d) for d in orig_data])
bad_idx = (plug_pos == -1) | (plug_pos > 40)

plug_pos[bad_idx] = 0
data = np.array([d[s:] for d,s in zip(orig_data, plug_pos)])

min_length = np.min([len(d) for d in data])
data = np.array([d[:min_length] for d in data])

sdf['data'] = list(data)
sdf['shift'] = list(plug_pos)
sdf['orig_data'] = list(orig_data)
sdf['good'][bad_idx == True] = False

sdf.to_pickle("/Users/Alex/Code/blurd/data.pandas")

# %%
sdf = pd.load("/Users/Alex/Code/blurd/data.pandas")

# %%
idx = np.argwhere([('IDA3' in v) and ('IDA2' in v) for v in sdf.tiff_file.values]).ravel()

# %%
sdf.tiff_file.values[idx]
# Out:
# array([ '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_ttuuvv_IDA3_ttuuvv_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_10min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_4min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_6min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-14-14 Blood Testing/IDA2_gghhII_IDA3_gghhII_8min.tiff'], dtype=object)

# %%
np.vstack(sdf.tiff_file_position.values[idx])
# Out:
# array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1],
#        [0, 0],
#        [0, 1],
#        [0, 2],
#        [0, 3],
#        [1, 0],
#        [1, 1]])

# %%
len(idx)
# Out:
# 180

# %%
# Let's also confine ourselves to one run-time and one assay type
sdf = pd.load("/Users/Alex/Code/blurd/data.pandas")
sdf = sdf[(sdf.run_time == 4) & (sdf.ida == "IDA2") & (sdf.good == True) & (sdf.blood_type != "")]# & (sdf.blood_type != "normal")]
isdf = sdf.copy()

# %%
data = np.vstack(isdf.data.values)

# %%
figure(figsize=(20,3))
imshow(data[:,1:].T)
# xlim(0,20)
figure(figsize=(20,2))
plot(data[:,1:].max(1))
axis('tight')
# xlim(0,20)
# Out:
# (0.0, 269.0, 0.44039556384086609, 0.87688857316970825)

# %%
tt_idx = isdf.MCV/isdf.RBC < 13
isdf['blood_type'][tt_idx] = 'tt'
isdf['blood_type'][tt_idx==False] = 'ida'

# %% [raw]
# # Change micro/hypo cutoff value for IDA to <1.5 instead of 1
# # 1.5 to try
# new_cutoff = 1.5
# old_cutoff = 1.0
# tt_idx = isdf[']
# idx = (isdf['%Micro/%Hypo Ratio'] < new_cutoff) & (isdf['%Hypo'] > 5)
# isdf[idx]['blood_type'] = 'ida'

# %% [markdown]
# ### The Agenda
#
# Things to try/change in data analysis
#
#
# ·         Consider hemolysis in plasma - try to cut off the tube in order to exclude the plasma/lysed RBCs
#
# ·         Bin the data by HGB (hemoglobin) or HCT (hematocrit)
#
# ·         Bin data into cutoff regimes for % hypo - can we do discrete or continuous categories?
#
# ·         Pull out and analyze the 8% of tests that the learning software is not calling as positive and analyze them
#
# ·         Check if any (false) positives have a normal MCH but a high hypo --> suggesting swollen cells.

# %%
dd = np.vstack(isdf['data'].values)

# %%
kmeans = KMeans(12).fit(dd)
idx = np.argsort(kmeans.labels_)

# %% [markdown]
# ### Bird's-eye view of false and true positives

# %%
data = np.vstack(sdf['data'].values)

# %%
sdf.tiff_file[idx[12:24]].values
# Out:
# array([ '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff',
#        '/Users/Alex/Dropbox/Science/side projects/Blood Testing/data/3-11-14 Blood Testing/IDA2_GGhhii_IDA3_GGhhii_2min.tiff'], dtype=object)

# %%
figure(figsize=(10,2))
imshow(np.swapaxes(sdf.image.values[idx[18]].astype('uint8'), 0,1));  yticks([]); axis('tight'); axis('off');

# %%
imshow(data[idx[:12]].T)

# %%
plot(data[idx[:12][::2]].T);
figure()
plot(data[idx[:12][1::2]].T);

# %%
idx = np.argwhere(kmeans.labels_==7).ravel()

# %%
isdf.columns
# Out:
# Index([u'%Hyper', u'%Hypo', u'%Macro', u'%Micro', u'%Micro/%Hypo Ratio', u'Age', u'Age Units', u'CH', u'CHCM', u'HCT', u'HDW', u'HGB', u'MCH', u'MCHC', u'MCV', u'MPV', u'PLT', u'RBC', u'RDW', u'Sex', u'WCB', u'blood_type', u'data', u'excel_file', u'experiment_index', u'good', u'ida', u'image', u'run_time', u'sample', u'sample_index', u'shift', u'tiff_file', u'tiff_file_position', u'orig_data'], dtype='object')

# %%
for i in idx:
    figure(figsize=(10,2))
    imshow(np.swapaxes(isdf.image.values[i].astype('uint8'), 0,1));  yticks([]); axis('tight'); axis('off'); 
    title(isdf.tiff_file.values[i] + "\n" + str(isdf.tiff_file_position.values[i]))

# %%
figure(figsize=(20,6))
gs = GridSpec(5,1, height_ratios=[2,2,2,1,10], hspace=0)
subplot(gs[0])
imshow((isdf.blood_type == "tt")[None,idx], cmap='bone')
ylabel("TT"); yticks([])
subplot(gs[1])
imshow((isdf.blood_type == "ida")[None,idx], cmap='bone')
ylabel("IDA"); yticks([])
subplot(gs[2])
ida_diagnosis = isdf['%Micro'].values[idx] / isdf['%Hypo'].values[idx] < 1.0
imshow(ida_diagnosis[None,:], cmap='bone')
ylabel("Micro\n/Hypo\n < 1"); yticks([])
axis('tight')
subplot(gs[3])
imshow(kmeans.labels_[idx][None,:], cmap='Paired'); axis('off')
subplot(gs[4])
imshow(dd[idx].T)

# %%
orig_blood_type = isdf.blood_type.copy()
isdf.blood_type[(isdf.blood_type == "ida") | (isdf.blood_type == "tt")] = "anemic"
data = np.vstack(isdf.data)
labels = isdf.blood_type.values
y,unique_y = unique_indices(labels)
y = y.astype('int32')  

guess_labels, true_labels, test_idx, yscores = classify(data[:,:120], y, n_folds=100, C=100)
# Out:
# Precision: 0.940373, Recall: 0.933556

# %%
# Consider hemolysis in plasma - try to cut off the tube in order to exclude the plasma/lysed RBCs
cutoff = 120
figure(figsize=(4,4))
I = np.hstack(isdf.image.values[0:6])
imshow(I)
hlines(cutoff, 0, I.shape[1])

# %% [markdown]
# ### Bin data for classification
#
# We want to be able to predict bloodwork results with the multi-phase assay.
# A simple way to try this is to roughly bin the data by some blood parameter, and do multi-class logistic regression.

# %%
# Bin the data by HGB (hemoglobin)
hemoglobin = isdf['HGB'].values.astype('float32')
bins = np.linspace(hemoglobin.min(), hemoglobin.max(), 3) # TODO: rational bins
hemoglobin_bins = np.digitize(hemoglobin, bins, right=True)

data = np.vstack(isdf.data)
labels = hemoglobin_bins
guess_labels, true_labels, test_idx, yscores = classify(data, labels, n_folds=50, C=0.03)
# Out:
# Precision: 0.647457, Recall: 0.643948

# %%
# Bin by HCT (hematocrit)
hematocrit = isdf['HCT'].values.astype('float32')
bins = np.linspace(hematocrit.min(), hematocrit.max(), 3) # TODO: rational bins
hematocrit_bins = np.digitize(hematocrit, bins, right=True)

data = np.vstack(isdf.data)
labels = hematocrit_bins
guess_labels, true_labels, test_idx, yscores = classify(data, labels, n_folds=50, C=0.03)
# Out:
# Precision: 0.659698, Recall: 0.610725

# %%
# Bin data into cutoff regimes for % hypo - can we do discrete or continuous categories?
hypo = np.array(isdf['%Hypo'].values, dtype='float32')
bins = np.linspace(0, 100, 10)
hypo_bins = np.digitize(hypo, bins, right=True)

data = np.vstack(isdf.data)
labels = hypo_bins
guess_labels, true_labels, test_idx, yscores = classify(data, labels, n_folds=50, C=0.03)
# Out:
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [4]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4].
# -c:15: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [7]. The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4 5 7].
# -c:15: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 5].
# -c:15: UserWarning: The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [4]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [5 7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4 7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5 7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [5 7].
# -c:15: UserWarning: The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 5].
# -c:15: UserWarning: The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [4]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4].
# -c:15: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [4]. The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4 5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [3 7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 7].
# -c:15: UserWarning: The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The sum of true positives and false negatives are equal to zero for some labels. Recall is ill defined for those labels [4 7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 5 7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [7].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 5 7].
# -c:15: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [4 5].
# -c:15: UserWarning: The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4 5].
# -c:15: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [5 7]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [3 4 5 7].
# Precision: 0.690373, Recall: 0.691111

# %%
# Pull out and analyze the 8% of tests that the learning software is not calling as positive and analyze them
orig_blood_type = isdf.blood_type.copy()
isdf.blood_type[(isdf.blood_type == "ida") | (isdf.blood_type == "tt")] = "anemic"
data = np.vstack(isdf.data)
labels = isdf.blood_type.values
y,unique_y = unique_indices(labels)
y = y.astype('int32')  
n_folds = 50
guess_labels, true_labels, test_idx, yscores = classify(data, y, n_folds=n_folds, C=0.03)
# Out:
# Precision: 0.923666, Recall: 0.961357

# %%
false_calls = np.sort(np.hstack([tidx[g!=t] for g,t,tidx in zip(guess_labels, true_labels, test_idx)]))
n_false_calls_per_sample = np.bincount(false_calls, minlength=len(isdf))/float(n_folds)
hard_samples = np.argwhere(n_false_calls_per_sample > 0).ravel()
easy_samples = np.argwhere(n_false_calls_per_sample == 0).ravel()

# %%
# It looks like there's a relatively limited population of "hard" samples
plot(np.sort(n_false_calls_per_sample))
ylabel("Percent time sample mis-called")
xlabel("Sorted sample ID")

# %%
isdf.iloc[easy_samples][['%Hyper', '%Hypo', '%Macro', '%Micro/%Hypo Ratio', 'Age', 'MCH']]
# Out:
#     %Hyper %Hypo %Macro %Micro/%Hypo Ratio         Age   MCH
# 24     2.2  11.9    0.1               1.39           4  25.2
# 25     2.2  11.9    0.1               1.39           4  25.2
# 26     0.1  70.7    1.4               0.05          32  24.9
# 27     0.1  70.7    1.4               0.05          32  24.9
# 28     1.2  31.5    8.2               0.07    1.333333  28.4
# 29     1.2  31.5    8.2               0.07    1.333333  28.4
# 30     0.5  12.2    4.1               0.11           2  28.5
# 31     0.5  12.2    4.1               0.11           2  28.5
# 32     0.5  20.4    0.2               0.42          14  23.6
# 34     0.5  24.1      0               0.75          19  21.3
# 35     0.5  24.1      0               0.75          19  21.3
# 84     0.6  13.3      5               0.06   0.8333333    30
# 85     0.6  13.3      5               0.06   0.8333333    30
# 86     0.3  28.9      3               0.15   0.4166667  26.5
# 87     0.3  28.9      3               0.15   0.4166667  26.5
# 88     0.6  22.9    6.7               0.03   0.8333333  29.9
# 89     0.6  22.9    6.7               0.03   0.8333333  29.9
# 90     1.1   6.8    2.2               0.19          13    29
# 91     1.1   6.8    2.2               0.19          13    29
# 92       1  16.3    1.1               0.26   0.3333333  27.3
# 93       1  16.3    1.1               0.26   0.3333333  27.3
# 94     0.3  30.3    0.5               0.18          20  24.8
# 95     0.3  30.3    0.5               0.18          20  24.8
# 148    2.9   0.3    0.7               2.88  0.02465753  31.1
# 149    2.9   0.3    0.7               2.88  0.02465753  31.1
# 150    2.3   0.3    0.1               3.22          15  29.1
# 151    2.3   0.3    0.1               3.22          15  29.1
# 152    0.9   0.3    0.3               3.61          28  28.3
# 153    0.9   0.3    0.3               3.61          28  28.3
# 154    1.1   0.1    0.1                4.8          16  28.8
# 155    1.1   0.1    0.1                4.8          16  28.8
# 204    2.7   2.3    0.1               0.77           2  28.3
# 205    2.7   2.3    0.1               0.77           2  28.3
# 206    2.1   0.4    0.6               2.33  0.02465753  29.7
# 207    2.1   0.4    0.6               2.33  0.02465753  29.7
# 208    0.8   0.1    0.5                2.9          18  31.6
# 209    0.8   0.1    0.5                2.9          18  31.6
# 211    0.9   1.1    0.1               1.18          17  27.8
# 214    1.8   2.6    1.3               0.25   0.6666667  30.3
# 215    1.8   2.6    1.3               0.25   0.6666667  30.3
# 504    0.2  28.3      0               0.37          16  21.7
# 505    0.2  28.3      0               0.37          16  21.7
# 506    2.2  27.6    0.9               0.07          23  27.1
# 507    2.2  27.6    0.9               0.07          23  27.1
# 508    1.8  27.3    0.2               0.77           4  22.8
# 509    1.8  27.3    0.2               0.77           4  22.8
# 510    0.2  12.1      0               0.52           7  24.3
# 511    0.2  12.1      0               0.52           7  24.3
# 512    0.7  42.2    0.9               0.08    1.166667    25
# 514    0.2  21.8      0                0.2           3  23.8
# 515    0.2  21.8      0                0.2           3  23.8
# 564    0.2  15.6   14.3               0.05          13  32.8
# 565    0.2  15.6   14.3               0.05          13  32.8
# 570    0.3  21.6    0.1               0.39          14  23.2
# 571    0.3  21.6    0.1               0.39          14  23.2
# 572    0.5  15.3    3.4               0.16   0.4166667  28.4
# 573    0.5  15.3    3.4               0.16   0.4166667  28.4
# 624      1   0.2    0.3               2.65          12  30.1
# 625      1   0.2    0.3               2.65          12  30.1
# 626    0.6   0.2    1.3               1.12          14  31.7
#        ...   ...    ...                ...         ...   ...
#
# [245 rows x 6 columns]

# %%
isdf.iloc[hard_samples][['%Hyper', '%Hypo', '%Macro', '%Micro/%Hypo Ratio', 'Age', 'MCH']]
# Out:
#      %Hyper %Hypo %Macro %Micro/%Hypo Ratio         Age   MCH
# 33      0.5  20.4    0.2               0.42          14  23.6
# 210     0.9   1.1    0.1               1.18          17  27.8
# 212     1.1   0.3    0.1               3.85          11  26.9
# 213     1.1   0.3    0.1               3.85          11  26.9
# 513     0.7  42.2    0.9               0.08    1.166667    25
# 566     2.9   4.5    4.9               3.64  0.05753425  26.7
# 567     2.9   4.5    4.9               3.64  0.05753425  26.7
# 568     0.1  12.8    0.7               0.31          12  26.8
# 569     0.1  12.8    0.7               0.31          12  26.8
# 689     1.2   3.9    1.9               0.15   0.6666667  31.2
# 1043    0.6  11.9      2               0.15           2  27.6
# 1461    1.6   0.2    0.2               2.84          16  29.3
# 1462    0.9   0.1    1.3               1.05          22  31.9
# 1463    0.9   0.1    1.3               1.05          22  31.9
# 1680    0.3   0.5      0               2.84          12  28.4
# 1686    0.5   1.5      0               1.49           5  27.3
# 1687    0.5   1.5      0               1.49           5  27.3
# 1689      1   1.4    0.4               0.64         0.5  29.2
# 1841    1.5  14.6    1.3               0.08          19  28.7
# 1847    1.1   0.8      0              16.83    1.083333  24.5
# 1848    1.1   0.8      0              16.83    1.083333  24.5
# 2319    1.3   3.3    2.1                3.9           4  29.3
# 2320    1.3   3.3    2.1                3.9           4  29.3
# 2325    0.2   5.7      0               1.98   0.3333333  25.7
# 2326    0.2   5.7      0               1.98   0.3333333  25.7
#
# [25 rows x 6 columns]

# %%
plot(np.linspace(0,1,len(hard_samples)), np.sort(isdf.iloc[hard_samples]['MCH']))
plot(np.linspace(0,1,len(easy_samples)), np.sort(isdf.iloc[easy_samples]['MCH']))
legend(["Hard samples", "Easy samples"])

# %%
for val in ["MCHC", "MCH", "MCV", "HGB", "HCT", "RDW", "%Hypo", "%Micro"]:
    figure()
    this_range = (isdf[val].min(), isdf[val].max())
    hist(isdf.iloc[easy_samples][val].values, bins=15, range=this_range)
    hist(isdf.iloc[hard_samples][val].values, bins=15, range=this_range)
    legend(["Easy samples", "Hard samples"])
    xlabel(val)
    ylabel("Counts")

# %%
# Bad samples: 
zip((100*n_false_calls_per_sample[hard_samples]).astype('int32'), 
    isdf.sample.iloc[hard_samples], 
    [s.split("/")[-1] for s in isdf.excel_file.iloc[hard_samples].values])
# Out:
# [(4, 'E', '1-12-14 Blood Info.xlsx'),
#  (10, 'V', '1-12-14 Blood Info.xlsx'),
#  (6, 'W', '1-12-14 Blood Info.xlsx'),
#  (6, 'W', '1-12-14 Blood Info.xlsx'),
#  (6, 'E', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (4, 'H', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (2, 'H', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (18, 'I', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (26, 'I', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (6, 'U', '1-9-14 Blood Data with Intensity Data.xlsx'),
#  (10, 'I', '3-11-14 Blood Info.xlsx'),
#  (2, 'R', '3-14-14 Blood Data.xlsx'),
#  (6, 'S', '3-14-14 Blood Data.xlsx'),
#  (10, 'S', '3-14-14 Blood Data.xlsx'),
#  (4, 'N', '3-20-14 Blood Data.xlsx'),
#  (10, 'Q', '3-20-14 Blood Data.xlsx'),
#  (14, 'Q', '3-20-14 Blood Data.xlsx'),
#  (18, 'R', '3-20-14 Blood Data.xlsx'),
#  (14, 'B', '3-6-14 Blood Data.xlsx'),
#  (22, 'E', '3-6-14 Blood Data.xlsx'),
#  (20, 'E', '3-6-14 Blood Data.xlsx'),
#  (22, 'A', '4-10-14 Blood Data.xlsx'),
#  (28, 'A', '4-10-14 Blood Data.xlsx'),
#  (6, 'D', '4-10-14 Blood Data.xlsx'),
#  (8, 'D', '4-10-14 Blood Data.xlsx')]
